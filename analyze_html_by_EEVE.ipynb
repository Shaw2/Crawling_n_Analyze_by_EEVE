# %%
from bs4 import BeautifulSoup
import requests

def clean_html(html):
    """필요 없는 태그를 제거하는 함수"""
    soup = BeautifulSoup(html, "html.parser")

    # 제거할 태그 목록
    remove_tags = ["script", "style", "meta", "link", "iframe", "embed", "object", "noscript"]

    for tag in soup.find_all(remove_tags):
        tag.decompose()  # 해당 태그 제거

    return soup.prettify()

# %%
# # 테스트할 URL (예제)
# url = "https://dlchemical.co.kr/"
# response = requests.get(url)

# if response.status_code == 200:
#     clean_content = clean_html(response.text)
#     print(clean_content)  # 정리된 HTML 출력
# else:
#     print("페이지를 가져오지 못했습니다.")
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <title>
#    DL케미칼
#   </title>
#   <!--<link rel="stylesheet" type="text/css" href="/assets/ko/library/select2/select2.min.css" />-->
#  </head>
#  <body>
#   <div id="skip">
#    <a href="#content">
#     본문 바로가기
#    </a>
#    <a href="#header">
#     주메뉴 바로 가기
#    </a>
#   </div>
#   <div class="c-wrap">
#    <div class="c-header" id="header">
#     <div class="c-header_aligner">
#      <h1 class="c-h1">
#       <a class="c-logo" href="/ko">
#        DL Chemical
#       </a>
#      </h1>
#      <div class="c-gnb">
#       <ul class="c-gnb_list">
#        <li class="c-gnb_item">
#         <a class="c-gnb_link" href="/ko/intro/info">
#          소개
#         </a>
#        </li>
#        <li class="c-gnb_item">
#         <a class="c-gnb_link" href="/ko/biz/polyethylene">
#          제품
#         </a>
#        </li>
#        <li class="c-gnb_item">
#         <a class="c-gnb_link" href="/ko/esg/management">
#          ESG
#         </a>
#        </li>
#        <li class="c-gnb_item">
#         <a class="c-gnb_link" href="/ko/media/newsroom">
#          미디어
#         </a>
#        </li>
#        <li class="c-gnb_item">
#         <a class="c-gnb_link" href="/ko/recruit">
#          채용
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="c-navi">
#       <a class="c-navi_link c-navi_link--search" href="#">
#        찾기
#       </a>
#       <a class="c-navi_link c-navi_link--drawer" href="#drawer">
#        <span>
#         메뉴
#        </span>
#        <span>
#         닫기
#        </span>
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="c-search" id="search">
#     <div class="c-search_alinger">
#      <div class="c-search_input">
#       <form action="/ko/search" autocomplete="off" name="searchPopForm">
#        <input autocomplete="off" id="" name="search_text" placeholder="검색어를 입력해주세요" type="text"/>
#        <label for="btnSearch" id="btnPopSearch">
#         검색
#        </label>
#       </form>
#      </div>
#     </div>
#    </div>
#    <div class="c-drawer" id="drawer">
#     <div class="c-drawer_aligners">
#      <div class="c-drawer_aligner">
#       <div class="c-drawer_lang">
#        <a class="active" href="#" title="선택됨">
#         KOR
#        </a>
#        <!-- active 클래스 추가 시 활성화 -->
#        <a href="/en">
#         ENG
#        </a>
#        <a href="/cn">
#         CHN
#        </a>
#       </div>
#       <div class="c-drawer_icons">
#        <a class="c-drawer_icon c-drawer_icon--youtube" href="https://www.youtube.com/c/DL%EB%94%94%EC%97%98" target="_blank" title="새창열림">
#         youtube
#        </a>
#       </div>
#       <div class="c-drawer_accordion">
#        <div class="c-drawer_box">
#         <a class="c-drawer_trigger" href="#">
#          소개
#         </a>
#         <div class="c-drawer_cont">
#          <dl>
#           <dt>
#            <a href="/ko/intro/info">
#             정보
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/info">
#               기업정보
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/info?anchor=2">
#               CEO인사말
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/info?anchor=3">
#               사업영역
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/info?anchor=4">
#               재무정보
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/info?anchor=5">
#               CI/BI
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/info?anchor=6">
#               연혁
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/info?anchor=7">
#               Contact
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#          <dl>
#           <dt>
#            <a href="/ko/intro/rnd">
#             R&amp;D
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/rnd">
#               R&amp;D 소개
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/rnd?anchor=2">
#               분야 및 실적
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#          <dl>
#           <dt>
#            <a href="/ko/intro/highlights">
#             그룹 Highlights
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/highlights">
#               DL 그룹
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/highlights?anchor=2">
#               건설
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/highlights?anchor=3">
#               석유화학/에너지
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/highlights?anchor=4">
#               레저/문화/교육
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#         </div>
#        </div>
#        <div class="c-drawer_box">
#         <a class="c-drawer_trigger" href="#">
#          제품
#         </a>
#         <div class="c-drawer_cont">
#          <dl>
#           <dt>
#            <a href="/ko/biz/polyethylene">
#             Polyethylene
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/biz/polyethylene?brand_type=d.fine">
#               D.FINE
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/biz/polyethylene?brand_type=d.xpoly">
#               D.XPOLY
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#          <dl>
#           <dt>
#            <a href="/ko/biz/polybutene">
#             Polybutene
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/biz/polybutene">
#               D.POLYBUTENE
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#          <dl>
#           <dt>
#            <a href="/ko/biz/synthetic">
#             EPO
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/biz/synthetic">
#               D.SYNOL
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#         </div>
#        </div>
#        <div class="c-drawer_box">
#         <a class="c-drawer_trigger" href="#">
#          ESG
#         </a>
#         <div class="c-drawer_cont">
#          <dl>
#           <dt>
#            <a href="/ko/esg/management">
#             ESG 경영
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/management?anchor=2">
#               지속가능경영보고서
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#          <dl>
#           <dt>
#            <a href="/ko/esg/hse">
#             안전·보건·환경(HSE) 경영
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/hse">
#               HSE 방침
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/hse?anchor=2">
#               HSE 목표
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/hse?anchor=3">
#               HSE 경영시스템
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/hse?anchor=4">
#               HSE 활동
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#          <dl>
#           <dt>
#            <a href="/ko/esg/proper">
#             정도경영
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/proper">
#               소개
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/proper?anchor=2">
#               공개경영
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/proper?anchor=3">
#               윤리경영
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/proper?anchor=4">
#               공정거래자율준수(CP)
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/proper?anchor=5">
#               사회적 책임(CSR)
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/proper?anchor=7">
#               사이버 신문고
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#          <dl>
#           <dt>
#            <a href="/ko/esg/winwin">
#             상생경영
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/winwin">
#               소개
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/winwin?anchor=2">
#               협력사 동반성장
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/winwin?anchor=3">
#               사회공헌
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#         </div>
#        </div>
#        <div class="c-drawer_box">
#         <a class="c-drawer_trigger" href="#">
#          미디어
#         </a>
#         <div class="c-drawer_cont">
#          <dl>
#           <dt>
#            <a href="/ko/media/newsroom">
#             뉴스룸
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/media/newsroom?ntype=CD_NWSR_CATE001">
#               보도자료
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/media/newsroom?ntype=CD_NWSR_CATE002">
#               알립니다
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#         </div>
#        </div>
#        <div class="c-drawer_box">
#         <a class="c-drawer_trigger" href="/ko/recruit">
#          채용
#         </a>
#        </div>
#       </div>
#       <div class="c-drawer_footer">
#        <div class="c-drawer_navibox">
#         <div class="c-drawer_navi">
#          <a href="/policy/privacy">
#           <span>
#            개인정보처리방침
#           </span>
#          </a>
#          <a href="/policy/video">
#           <span>
#            영상정보기기 운영관리방침
#           </span>
#          </a>
#          <a class="btnLayerPopup" data-target=".email-policy" href="#">
#           <span>
#            이메일무단수집거부
#           </span>
#          </a>
#          <a href="https://eprov.dlchemical.co.kr" target="_blank">
#           <span>
#            인터넷 구매시스템
#           </span>
#          </a>
#          <a href="https://logipartner.daelimcorp.co.kr" target="_blank">
#           <span>
#            출하정보 시스템
#           </span>
#          </a>
#          <!-- s: 220802 -->
#          <a href="/ko/esg/proper?anchor=7" target="_blank">
#           <span>
#            사이버 신문고
#           </span>
#          </a>
#          <!-- e: 220802 -->
#         </div>
#        </div>
#        <div class="c-drawer_info">
#         <p>
#          서울특별시 종로구 통일로 134 D타워
#          <br class="mobile"/>
#          돈의문 26층 DL케미칼
#         </p>
#         <p>
#          Copyright © 2022 DL케미칼. All rights reserved.
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#     <a class="c-drawer_close" href="#">
#      메뉴닫기
#     </a>
#    </div>
#    <div class="c-container" id="content">
#     <div class="main">
#      <section class="m-section" id="section01">
#       <div class="m-visual">
#        <div class="m-visual_aligner">
#         <div class="m-visual_txtbox">
#          <div class="m-visual_heading">
#           <p data-aos="fade-left" data-aos-delay="100" data-aos-duration="500">
#            케미칼의
#           </p>
#           <p data-aos="fade-left" data-aos-delay="200" data-aos-duration="500">
#            기본이 됩니다
#           </p>
#          </div>
#          <div class="m-visual_since" data-aos="fade-up" data-aos-delay="300" data-aos-duration="800">
#           since
#           <strong>
#            1979
#           </strong>
#          </div>
#          <div class="m-visual_txt" data-aos="fade-up" data-aos-delay="300" data-aos-duration="1000">
#           DL케미칼은 세계 최고 수준의 R&amp;D 역량과
#           <br class="mobile"/>
#           전략적 제휴를 기반으로
#           <br/>
#           세계 수준의 석유화학 기업으로 거듭나고 있습니다
#          </div>
#         </div>
#         <div class="m-picture" data-aos="fade-up" data-aos-delay="300" data-aos-duration="800">
#          <div class="m-picture_txtbox">
#           <div class="m-picture_txt m-picture_txt-1">
#            World Leading
#            <br/>
#            Petrochemical
#            <br/>
#            Company
#           </div>
#           <div class="m-picture_txt m-picture_txt-2">
#            Chemical
#           </div>
#          </div>
#          <div class="m-picture_image" data-aos="fade" data-aos-anchor=".m-picture_txt-2">
#           <img alt="" src="/assets/ko/images/pages/m-picture.png"/>
#          </div>
#         </div>
#        </div>
#       </div>
#      </section>
#      <section class="m-section" id="section02">
#       <div class="m-technology">
#        <div class="m-technology_heading" data-aos="fade">
#         <div class="c-aligner">
#          <div class="m-heading">
#           <div class="m-heading_detail" data-aos="fade-up" data-aos-delay="100" data-aos-duration="500">
#            신뢰의 기본이 됩니다
#           </div>
#           <p class="m-heading_txt" data-aos="fade-up" data-aos-delay="200" data-aos-duration="500">
#            DL케미칼은 신뢰받는
#           </p>
#           <p class="m-heading_txt" data-aos="fade-up" data-aos-delay="250" data-aos-duration="500">
#            기술력을 바탕으로
#           </p>
#           <p class="m-heading_txt" data-aos="fade-up" data-aos-delay="300" data-aos-duration="500">
#            고객의 가치를 향상시킵니다
#           </p>
#          </div>
#         </div>
#        </div>
#        <div class="m-technology_slider">
#         <div class="c-aligner">
#          <div class="m-slider">
#           <div class="m-slider_list" data-aos="fade-left" data-aos-delay="200" data-aos-duration="1000">
#            <div class="m-slider_item active">
#             <div class="m-technology_box">
#              <div class="m-technology_images">
#               <div class="m-technology_image">
#                <img alt="" src="/assets/ko/images/pages/m-technology_image-0.jpg"/>
#               </div>
#              </div>
#              <div class="m-technology_cont">
#               <div class="m-technology_logo">
#                <img alt="DL Chemical" src="/assets/ko/images/pages/m-technology_logo-0.svg"/>
#               </div>
#               <div class="m-technology_sheading">
#                독자적 메탈로센 기술의 PE,
#                <br>
#                 세계 점유율 No.1 PB,
#                 <br>
#                  프리미엄 점도조절제 EPO
#                 </br>
#                </br>
#               </div>
#               <div class="m-technology_txt">
#                케미칼 제품 생산능력,
#                <em>
#                 915KTA
#                </em>
#                <br>
#                 2021년 기준 매출액,
#                 <em>
#                  1.6조원
#                 </em>
#                </br>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-technology_box">
#              <div class="m-technology_images">
#               <div class="m-technology_image">
#                <img alt="" src="/assets/ko/images/pages/m-technology_image-1.jpg"/>
#               </div>
#              </div>
#              <div class="m-technology_cont">
#               <div class="m-technology_logo">
#                <img alt="KRATON" src="/assets/ko/images/pages/m-technology_logo-1.svg"/>
#               </div>
#               <div class="m-technology_sheading">
#                글로벌 스페셜티 폴리머와
#                <br/>
#                파인 케미칼
#                <br/>
#                시장의 선도 기업
#               </div>
#               <div class="m-technology_txt">
#                약
#                <em>
#                 1,000
#                </em>
#                개 이상의 기술특허
#                <br/>
#                바이오 케미칼 생산 능력,
#                <em>
#                 700KTA
#                </em>
#                <br/>
#                2021년 기준 매출액 약,
#                <em>
#                 2조원
#                </em>
#               </div>
#               <div class="m-technology_mores">
#                <a class="m-technology_more" href="https://kraton.com" target="_blank">
#                 more
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-technology_box">
#              <div class="m-technology_images">
#               <div class="m-technology_image">
#                <img alt="" src="/assets/ko/images/pages/m-technology_image-2.jpg"/>
#               </div>
#              </div>
#              <div class="m-technology_cont">
#               <div class="m-technology_logo">
#                <img alt="DL FnC" src="/assets/ko/images/pages/m-technology_logo-2.svg"/>
#               </div>
#               <div class="m-technology_sheading">
#                BOPP Film,
#                <br>
#                 EVA Coated Film,
#                 <br>
#                  특수코팅 Film 전문회사
#                 </br>
#                </br>
#               </div>
#               <div class="m-technology_txt">
#                BOPP 생산 능력,
#                <em>
#                 32KTA
#                </em>
#                <br>
#                 2021년 기준 매출액 약,
#                 <em>
#                  950억원
#                 </em>
#                </br>
#               </div>
#               <div class="m-technology_mores">
#                <a class="m-technology_more" href="https://www.dlfnc.co.kr" target="_blank">
#                 more
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-technology_box">
#              <div class="m-technology_images">
#               <div class="m-technology_image">
#                <img alt="" src="/assets/ko/images/pages/m-technology_image-3.jpg"/>
#               </div>
#              </div>
#              <div class="m-technology_cont">
#               <div class="m-technology_logo">
#                <img alt="Cariflex" src="/assets/ko/images/pages/m-technology_logo-3.svg"/>
#               </div>
#               <div class="m-technology_sheading">
#                합성고무 및 합성고무 라텍스
#                <br>
#                 제조 및 판매
#                 <br>
#                  수술장갑 분야 글로벌 No.1
#                 </br>
#                </br>
#               </div>
#               <div class="m-technology_txt">
#                2021년 기준 매출액 약,
#                <em>
#                 2,600억원
#                </em>
#               </div>
#               <div class="m-technology_mores">
#                <a class="m-technology_more" href="https://www.cariflex.com" target="_blank">
#                 more
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-technology_box">
#              <div class="m-technology_images">
#               <div class="m-technology_image">
#                <img alt="" src="/assets/ko/images/pages/m-technology_image-4.jpg"/>
#               </div>
#              </div>
#              <div class="m-technology_cont">
#               <div class="m-technology_logo">
#                <img alt="D-REX Polymer" src="/assets/ko/images/pages/m-technology_logo-4.svg"/>
#               </div>
#               <div class="m-technology_sheading">
#                핫멜트 접착제 소재
#                <br>
#                 무정형 폴리 알파 올레핀
#                 <br/>
#                 (Amorphous Poly Alpha Olefin)
#                 <br/>
#                 전문회사
#                </br>
#               </div>
#               <div class="m-technology_txt">
#                2021년 12월 착공
#                <br/>
#                2023년 상반기
#                <em>
#                 4만톤
#                </em>
#                규모 생산 시작
#               </div>
#               <div class="m-technology_mores">
#                <a class="m-technology_more" href="https://www.drexpolymer.com/" target="_blank">
#                 more
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-technology_box">
#              <div class="m-technology_images">
#               <div class="m-technology_image">
#                <img alt="" src="/assets/ko/images/pages/m-technology_image-7.jpg"/>
#               </div>
#              </div>
#              <div class="m-technology_cont">
#               <div class="m-technology_logo">
#                <img alt="NOTARK" src="/assets/ko/images/pages/m-technology_logo-7.svg"/>
#               </div>
#               <div class="m-technology_sheading">
#                미래 제품을 개발 하는
#                <br/>
#                혁신 기업
#               </div>
#               <div class="m-technology_txt">
#                혁신 제품의 개발 및 상업화 위해 2023년 설립
#                <br/>
#                초고속 통신 장비용 절연 레진 노탁(Notark™ )개발
#                <br/>
#                미래 에너지 솔루션 용 이온 전도성 폴리머 등 다양한 기술 플랫폼 개발 중
#               </div>
#               <!-- 24.02.19 버튼 숨김처리
# 											<div class="m-technology_mores">
# 												<a href="https://www.notark.com" target="_blank" class="m-technology_more">more</a>
# 											</div>
# 											-->
#              </div>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-technology_box">
#              <div class="m-technology_images">
#               <div class="m-technology_image">
#                <img alt="" src="/assets/ko/images/pages/m-technology_image-5.jpg"/>
#               </div>
#              </div>
#              <div class="m-technology_cont">
#               <div class="m-technology_logo">
#                <img alt="Poly Mirae" src="/assets/ko/images/pages/m-technology_logo-5.svg"/>
#               </div>
#               <div class="m-technology_sheading">
#                <p>
#                 DL케미칼 50% : LyondellBasell 50%
#                </p>
#                마스크, 자동차 내외장재 용
#                <br/>
#                Specialty 폴리프로필렌
#                <br/>
#                전문회사
#               </div>
#               <div class="m-technology_txt">
#                PP 생산 능력,
#                <em>
#                 730KTA
#                </em>
#                <br/>
#                2021년 기준 매출액 약,
#                <em>
#                 1조원
#                </em>
#               </div>
#               <div class="m-technology_mores">
#                <a class="m-technology_more" href="https://www.polymirae.com" target="_blank">
#                 more
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-technology_box">
#              <div class="m-technology_images">
#               <div class="m-technology_image">
#                <img alt="" src="/assets/ko/images/pages/m-technology_image-6.jpg"/>
#               </div>
#              </div>
#              <div class="m-technology_cont">
#               <div class="m-technology_logo">
#                <img alt="YNCC" src="/assets/ko/images/pages/m-technology_logo-6-2.svg"/>
#               </div>
#               <div class="m-technology_sheading">
#                <p>
#                 DL케미칼 50% : 한화솔루션 50%
#                </p>
#                국내 최대 나프타 분해 업체
#                <br/>
#                에틸렌, 프로필렌, 부타디엔 등
#                <br/>
#                기초 원료 생산
#               </div>
#               <div class="m-technology_txt">
#                에틸렌 생산 능력,
#                <em>
#                 2300KTA
#                </em>
#                <br/>
#                프로필렌 생산 능력,
#                <em>
#                 1,300KTA
#                </em>
#                <br/>
#                2021년 기준 매출액 약,
#                <em>
#                 6조원
#                </em>
#               </div>
#               <div class="m-technology_mores">
#                <a class="m-technology_more" href="https://www.yncc.co.kr" target="_blank">
#                 more
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <!-- // 220423 퍼블 수정 -->
#         </div>
#        </div>
#       </div>
#      </section>
#      <section class="m-section m-section--none" id="section04">
#       <div class="m-info">
#        <div class="m-info_aligner">
#         <div class="m-info_box">
#          <div class="m-info_tabboxs">
#           <div class="m-info_tabbox">
#            <div class="m-info_heading" data-aos="fade-left" data-aos-delay="300" data-aos-duration="500">
#             혁신의 기본이 됩니다
#            </div>
#            <div class="m-info_tabs">
#             <ul class="m-info_tab">
#              <li data-aos="fade-up" data-aos-anchor=".m-info_tab" data-aos-delay="800" data-aos-duration="600">
#               <a href="#">
#                47년
#               </a>
#              </li>
#              <!-- active클래스 추가 시 활성화 -->
#              <li data-aos="fade-up" data-aos-anchor=".m-info_tab" data-aos-delay="850" data-aos-duration="600">
#               <a href="#">
#                기술 선도 기업
#               </a>
#              </li>
#              <li data-aos="fade-up" data-aos-anchor=".m-info_tab" data-aos-delay="900" data-aos-duration="600">
#               <a href="#">
#                세계 1위 제품
#               </a>
#              </li>
#              <li data-aos="fade-up" data-aos-anchor=".m-info_tab" data-aos-delay="1000" data-aos-duration="600">
#               <a href="#">
#                글로벌 기업 도약
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#          <div class="m-info_imagelistbox">
#           <div class="m-info_imagelists" data-aos="fade-up" data-aos-delay="1300" data-aos-duration="700">
#            <div class="m-info_imagelist">
#             <div class="m-info_imageitem">
#              <div class="m-info_imagebox">
#               <div class="m-info_image">
#                <img alt="" src="/assets/ko/images/pages/m-info_image-1.png"/>
#               </div>
#              </div>
#             </div>
#             <div class="m-info_imageitem">
#              <div class="m-info_imagebox">
#               <div class="m-info_image">
#                <img alt="" src="/assets/ko/images/pages/m-info_image-2.png"/>
#               </div>
#              </div>
#             </div>
#             <div class="m-info_imageitem">
#              <div class="m-info_imagebox">
#               <div class="m-info_image">
#                <img alt="" src="/assets/ko/images/pages/m-info_image-3.png"/>
#               </div>
#              </div>
#             </div>
#             <div class="m-info_imageitem">
#              <div class="m-info_imagebox">
#               <div class="m-info_image">
#                <img alt="" src="/assets/ko/images/pages/m-info_image-4.png"/>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="m-info_txtlist" data-aos="fade-right" data-aos-delay="1600" data-aos-duration="800">
#            <div class="m-info_txtitem active">
#             <div class="m-info_txtbox">
#              <div class="m-info_txt">
#               47 년 역사의 설비 및 생산 운영 노하우를 바탕으로
#               <br/>
#               DL케미칼은 석유화학업계의 선도 기업으로 성장하고 있습니다.
#              </div>
#             </div>
#            </div>
#            <div class="m-info_txtitem">
#             <div class="m-info_txtbox">
#              <div class="m-info_txt">
#               DL케미칼은 미국 시장에 기술을 수출한 국내 최초의 기업입니다. 또한, 세계 두번째로 차세대 메탈로센 폴리에틸렌의 개발에 성공, 그 기술력을 인정 받고 있습니다.
#              </div>
#             </div>
#            </div>
#            <div class="m-info_txtitem">
#             <div class="m-info_txtbox">
#              <div class="m-info_txt">
#               DL케미칼은 글로벌 폴리부텐(PB)시장의 1위 (오픈마켓 기준) 기업입니다.  또한, 합성고무를 생산하는 자회사인 카리플렉스는 수술용 고무장갑 원료 시장의 75%를 차지하고 있습니다.
#              </div>
#             </div>
#            </div>
#            <div class="m-info_txtitem">
#             <div class="m-info_txtbox">
#              <div class="m-info_txt">
#               DL케미칼은 미/유럽 SBC 시장
# 											1위 기업 크레이튼 인수,
# 											친환경 접착제 생산 기업 디렉스
# 											폴리머 설립 등 글로벌 시장으로
# 											도약하기 위한 준비를 마쳤습니다.
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="m-info_slide" data-aos="fade-up" data-aos-delay="800" data-aos-duration="800">
#           <div class="m-info_slidelist">
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </section>
#      <section class="m-section m-section--none" id="section05">
#       <div class="m-news">
#        <div class="m-news_heading">
#         <div class="c-aligner">
#          <div class="m-heading">
#           <div class="m-heading_detail" data-aos="fade-left" data-aos-delay="100" data-aos-duration="500">
#            성장의 기본이 됩니다
#           </div>
#           <p class="m-heading_txt" data-aos="fade-left" data-aos-delay="200" data-aos-duration="500">
#            환경을 위한 실천과
#            <br class="mobile"/>
#            고객과의 소통을 통해
#           </p>
#           <p class="m-heading_txt" data-aos="fade-left" data-aos-delay="250" data-aos-duration="500">
#            지속가능한 미래를 만들어갑니다
#           </p>
#          </div>
#         </div>
#        </div>
#        <div class="m-news_slider" data-aos="fade-left" data-aos-delay="350" data-aos-duration="1000">
#         <div class="c-aligner">
#          <div class="m-slider">
#           <div class="m-slider_list">
#            <div class="m-slider_item active">
#             <div class="m-news_box">
#              <div class="m-news_images">
#               <div class="m-news_image">
#                <img alt="DL케미칼, 국내 주요 대학 채용박람회로 인재 확보 나서 " src="/upload/news/thumb1/282/7K7dbkHdUKG.jpg"/>
#               </div>
#              </div>
#              <div class="m-news_cont">
#               <div class="m-news_date">
#                2023.03.03
#               </div>
#               <div class="m-news_subject">
#                DL케미칼, 국내 주요 대학 채용박람회로 인재 확보 나서
#               </div>
#               <div class="m-news_tag">
#                <span>
#                 #보도자료
#                </span>
#               </div>
#               <div class="m-news_mores">
#                <a class="m-news_more" href="https://www.dlchemical.co.kr/ko/media/newsroom/47" target="_blank">
#                 more
#                </a>
#               </div>
#              </div>
#              <a class="all-area-link" href="https://www.dlchemical.co.kr/ko/media/newsroom/47" target="_blank">
#               more
#              </a>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-news_box">
#              <div class="m-news_images">
#               <div class="m-news_image">
#                <img alt="DL케미칼, 따뜻한 연탄 나눔으로 에너지 소외계층 지원  " src="/upload/news/thumb1/281/4utlPKbtfo.jpg"/>
#               </div>
#              </div>
#              <div class="m-news_cont">
#               <div class="m-news_date">
#                2022.12.13
#               </div>
#               <div class="m-news_subject">
#                DL케미칼, 따뜻한 연탄 나눔으로 에너지 소외계층 지원
#               </div>
#               <div class="m-news_tag">
#                <span>
#                 #보도자료
#                </span>
#               </div>
#               <div class="m-news_mores">
#                <a class="m-news_more" href="https://www.dlchemical.co.kr/ko/media/newsroom/46" target="_blank">
#                 more
#                </a>
#               </div>
#              </div>
#              <a class="all-area-link" href="https://www.dlchemical.co.kr/ko/media/newsroom/46" target="_blank">
#               more
#              </a>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-news_box">
#              <div class="m-news_images">
#               <div class="m-news_image">
#                <img alt="준법경영 시스템 국제표준 ‘ISO 37301 인증 획득" src="/upload/news/thumb1/280/FJT7YAxOdKneLs8HhLbIIrvbrG5XcDn7x7e2WGr.jpg"/>
#               </div>
#              </div>
#              <div class="m-news_cont">
#               <div class="m-news_date">
#                2022.09.26
#               </div>
#               <div class="m-news_subject">
#                준법경영 시스템 국제표준 ‘ISO 37301 인증 획득
#               </div>
#               <div class="m-news_tag">
#                <span>
#                 #보도자료
#                </span>
#               </div>
#               <div class="m-news_mores">
#                <a class="m-news_more" href="https://www.dlchemical.co.kr/ko/media/newsroom/44" target="_blank">
#                 more
#                </a>
#               </div>
#              </div>
#              <a class="all-area-link" href="https://www.dlchemical.co.kr/ko/media/newsroom/44" target="_blank">
#               more
#              </a>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-news_box">
#              <div class="m-news_images">
#               <div class="m-news_image">
#                <img alt="DL케미칼, 수출용 제품에 재활용 포장백 대폭 적용" src="/upload/news/thumb1/279/LLWY1rRl.jpg"/>
#               </div>
#              </div>
#              <div class="m-news_cont">
#               <div class="m-news_date">
#                2022.06.27
#               </div>
#               <div class="m-news_subject">
#                DL케미칼, 수출용 제품에 재활용 포장백 대폭 적용
#               </div>
#               <div class="m-news_tag">
#                <span>
#                 #보도자료
#                </span>
#               </div>
#               <div class="m-news_mores">
#                <a class="m-news_more" href="https://www.dlchemical.co.kr/ko/media/newsroom/37" target="_self">
#                 more
#                </a>
#               </div>
#              </div>
#              <a class="all-area-link" href="https://www.dlchemical.co.kr/ko/media/newsroom/37" target="_self">
#               more
#              </a>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-news_box">
#              <div class="m-news_images">
#               <div class="m-news_image">
#                <img alt="DL케미칼, 환경공단 영농 폐비닐 재활용 MOU 체결" src="/upload/news/thumb1/277/7oyPD38.jpg"/>
#               </div>
#              </div>
#              <div class="m-news_cont">
#               <div class="m-news_date">
#                2022.05.10
#               </div>
#               <div class="m-news_subject">
#                DL케미칼, 환경공단 영농 폐비닐 재활용 MOU 체결
#               </div>
#               <div class="m-news_tag">
#                <span>
#                 #보도자료
#                </span>
#               </div>
#               <div class="m-news_mores">
#                <a class="m-news_more" href="https://www.dlchemical.co.kr/ko/media/newsroom/34" target="_self">
#                 more
#                </a>
#               </div>
#              </div>
#              <a class="all-area-link" href="https://www.dlchemical.co.kr/ko/media/newsroom/34" target="_self">
#               more
#              </a>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-news_box">
#              <div class="m-news_images">
#               <div class="m-news_image">
#                <img alt="DL케미칼 세계포장기구(WPO) 월드스타 어워드 수상" src="/upload/news/thumb1/276/3tUpFPdmLPoAVWxUxVp2gFwXTm2GVCFa53.png"/>
#               </div>
#              </div>
#              <div class="m-news_cont">
#               <div class="m-news_date">
#                2022.05.10
#               </div>
#               <div class="m-news_subject">
#                DL케미칼 세계포장기구(WPO) 월드스타 어워드 수상
#               </div>
#               <div class="m-news_tag">
#                <span>
#                 #알립니다
#                </span>
#               </div>
#               <div class="m-news_mores">
#                <a class="m-news_more" href="https://www.dlchemical.co.kr/ko/media/newsroom/32" target="_blank">
#                 more
#                </a>
#               </div>
#              </div>
#              <a class="all-area-link" href="https://www.dlchemical.co.kr/ko/media/newsroom/32" target="_blank">
#               more
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </section>
#     </div>
#    </div>
#    <div class="c-banner">
#     <div class="c-banner_aligner">
#      <div class="c-banner_box">
#       <div class="c-banner_slidebox">
#        <div class="c-banner_slide">
#         <div class="c-banner_list">
#         </div>
#        </div>
#        <div class="c-banner_function">
#         <div class="inline">
#          <div class="c-check">
#           <input id="banner-today" name="banner-today" type="checkbox">
#            <label for="banner-today">
#             오늘 다시보지 않음
#            </label>
#           </input>
#          </div>
#         </div>
#         <div class="inline">
#          <a class="c-banner_close" href="#">
#           팝업닫기
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="c-sharebox" style="display:none;">
#     <div class="c-share_snsbox">
#      <ul class="c-share_sns">
#       <li class="c-share_sns-2">
#        <a class="btnFacebook" href="#">
#         페이스북
#        </a>
#       </li>
#       <li class="c-share_sns-3">
#        <a class="btnTwitter" href="#">
#         트위터
#        </a>
#       </li>
#       <li class="c-share_sns-4">
#        <a class="btnBlog" href="#">
#         블로그
#        </a>
#       </li>
#       <li class="c-share_sns-5">
#        <a class="btnLinkedIn" href="#">
#         Linkedin
#        </a>
#       </li>
#       <li class="c-share_sns-7">
#        <a class="btnClipboard" href="#">
#         URL 복사
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="c-top">
#     <a href="#">
#      Top
#     </a>
#    </div>
#    <div class="c-footer">
#     <div class="c-footer_aligner">
#      <div class="c-footer_heading">
#       <a class="c-footer_logo" href="/">
#        DL Chemical
#       </a>
#      </div>
#      <ul class="c-footer_list">
#       <li>
#        <a href="/ko/policy/privacy">
#         개인정보처리방침
#        </a>
#       </li>
#       <li>
#        <a href="/ko/policy/video">
#         영상정보처리기기운영관리방침
#        </a>
#       </li>
#       <li>
#        <a class="btnLayerPopup" data-target=".email-policy" href="#">
#         이메일무단수집거부
#        </a>
#       </li>
#       <li>
#        <a href="/ko/esg/proper?anchor=7">
#         사이버 신문고
#        </a>
#       </li>
#      </ul>
#      <a class="c-partner_trigger" href="#partner">
#       계열사 바로가기
#      </a>
#      <div class="c-partner" id="partner">
#       <div class="c-partner_aligner">
#        <div class="c-partner_box">
#         <div class="c-partner_section">
#          <h2 class="c-partner_heading">
#           계열사 사이트
#          </h2>
#          <div class="c-partner_listboxs">
#           <div class="c-partner_listbox">
#            <h3 class="c-partner_sheading">
#             건설
#            </h3>
#            <ul class="c-partner_list">
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://www.dlenc.co.kr" target="_blank">
#               DL이앤씨
#              </a>
#             </li>
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://dlconstruction.co.kr" target="_blank">
#               DL건설
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="c-partner_listbox">
#            <h3 class="c-partner_sheading">
#             석유화학
#            </h3>
#            <ul class="c-partner_list">
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="#" target="_blank">
#               DL케미칼
#              </a>
#             </li>
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://www.dlfnc.co.kr" target="_blank">
#               DL에프앤씨
#              </a>
#             </li>
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://www.yncc.co.kr" target="_blank">
#               여천NCC
#              </a>
#             </li>
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://www.polymirae.com" target="_blank">
#               폴리미래
#              </a>
#             </li>
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://www.cariflex.com" target="_blank">
#               CARIFLEX
#              </a>
#             </li>
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://kraton.com" target="_blank" title="새창열림">
#               KRATON
#              </a>
#             </li>
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://www.drexpolymer.com" target="_blank" title="새창열림">
#               디렉스폴리머
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="c-partner_listbox">
#            <h3 class="c-partner_sheading">
#             에너지/제조
#            </h3>
#            <ul class="c-partner_list">
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="http://www.dlenergy.co.kr" target="_blank">
#               DL에너지
#              </a>
#             </li>
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="http://www.dlmotors.co.kr">
#               DL모터스
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="c-partner_listbox">
#            <h3 class="c-partner_sheading">
#             레저
#            </h3>
#            <ul class="c-partner_list">
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://www.glad-hotels.com" target="_blank">
#               글래드 호텔앤리조트
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="c-partner_listbox">
#            <h3 class="c-partner_sheading">
#             문화
#            </h3>
#            <ul class="c-partner_list">
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://daelimmuseum.org/daelimculturalfoundation" target="_blank">
#               대림문화재단
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="c-partner_listbox">
#            <h3 class="c-partner_sheading">
#             교육
#            </h3>
#            <ul class="c-partner_list">
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://www.suam.or.kr" target="_blank">
#               대림수암장학문화재단
#              </a>
#             </li>
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://www.daelim.ac.kr" target="_blank">
#               대림학원
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#         <div class="c-partner_section">
#          <div class="c-partner_halfs">
#           <div class="c-partner_half">
#            <h2 class="c-partner_heading">
#             브랜드 페이지
#            </h2>
#            <div class="c-partner_listboxs">
#             <div class="c-partner_listbox">
#              <ul class="c-partner_list">
#               <li class="c-partner_item">
#                <a class="c-partner_link" href="https://www.elife.co.kr" target="_blank">
#                 e편한세상
#                </a>
#               </li>
#               <li class="c-partner_item">
#                <a class="c-partner_link" href="https://www.acro.co.kr" target="_blank">
#                 아크로
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </div>
#           <div class="c-partner_half">
#            <h2 class="c-partner_heading">
#             기타/업무 관련 사이트
#            </h2>
#            <div class="c-partner_listboxs">
#             <div class="c-partner_listbox">
#              <ul class="c-partner_list">
#               <li class="c-partner_item">
#                <a class="c-partner_link" href="#">
#                 인터넷 구매시스템
#                </a>
#               </li>
#               <li class="c-partner_item">
#                <a class="c-partner_link" href="#">
#                 출하정보 시스템
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <a class="c-partner_close" href="#">
#          계열사 바로가기 팝업 닫기
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="c-popup email-policy">
#     <div class="c-popup_aligner">
#      <div class="c-popup_box">
#       <div class="c-popup_headings">
#        <div class="c-popup_heading">
#         이메일무단수집거부
#        </div>
#        <!-- 220509 퍼블리싱 수정 -->
#       </div>
#       <div class="c-popup_cont">
#        <div class="c-popup_txt">
#         본 웹사이트에 게시된 이메일 주소가 전자우편 수집 프로그램이나 그 밖의 기술적 장치를 이용한 무단으로 수집되는 것을 거부하며, 이를 위반 시
#         <em>
#          정보통신망법에 의해 형사처벌
#         </em>
#         됨을 유념하시기 바랍니다.
#         <br/>
#         <br/>
#         게시일 : 2010년 12월 1일
#        </div>
#        <div class="c-popup_buttons">
#         <a class="c-popup_button" href="#">
#          확인
#         </a>
#        </div>
#       </div>
#       <a class="c-popup_close" href="#">
#        팝업닫기
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %%
"C:/Users/Dolphinnn/VscodeProjects/Crawling_n_Analyze_by_EEVE/data/Enterprise_url_from_GDWEB.csv"

# %%
# !pip install ollama
# Out:
# Collecting ollama
#   Downloading ollama-0.4.7-py3-none-any.whl.metadata (4.7 kB)
# Collecting httpx<0.29,>=0.27 (from ollama)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting pydantic<3.0.0,>=2.9.0 (from ollama)
#   Downloading pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Collecting anyio (from httpx<0.29,>=0.27->ollama)
#   Downloading anyio-4.8.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: certifi in c:\users\dolphinnn\anaconda3\envs\pyt_conda_venv\lib\site-packages (from httpx<0.29,>=0.27->ollama) (2024.12.14)
# Collecting httpcore==1.* (from httpx<0.29,>=0.27->ollama)
#   Downloading httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in c:\users\dolphinnn\anaconda3\envs\pyt_conda_venv\lib\site-packages (from httpx<0.29,>=0.27->ollama) (3.4)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<0.29,>=0.27->ollama)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.9.0->ollama)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic<3.0.0,>=2.9.0->ollama)
#   Downloading pydantic_core-2.27.2-cp310-cp310-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-extensions>=4.12.2 (from pydantic<3.0.0,>=2.9.0->ollama)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\dolphinnn\anaconda3\envs\pyt_conda_venv\lib\site-packages (from anyio->httpx<0.29,>=0.27->ollama) (1.2.2)
# Collecting sniffio>=1.1 (from anyio->httpx<0.29,>=0.27->ollama)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Downloading ollama-0.4.7-py3-none-any.whl (13 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ---------------------------------------- 0.0/73.5 kB ? eta -:--:--
#    ---------------------------------------- 73.5/73.5 kB 4.2 MB/s eta 0:00:00
# Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.6 kB ? eta -:--:--
#    ---------------------------------------- 78.6/78.6 kB 4.3 MB/s eta 0:00:00
# Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
#    ---------------------------------------- 0.0/431.7 kB ? eta -:--:--
#    --------------------------------------- 431.7/431.7 kB 28.1 MB/s eta 0:00:00
# Downloading pydantic_core-2.27.2-cp310-cp310-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 123.3 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading anyio-4.8.0-py3-none-any.whl (96 kB)
#    ---------------------------------------- 0.0/96.0 kB ? eta -:--:--
#    ---------------------------------------- 96.0/96.0 kB ? eta 0:00:00
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: typing-extensions, sniffio, h11, annotated-types, pydantic-core, httpcore, anyio, pydantic, httpx, ollama
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
# Successfully installed annotated-types-0.7.0 anyio-4.8.0 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 ollama-0.4.7 pydantic-2.10.6 pydantic-core-2.27.2 sniffio-1.3.1 typing-extensions-4.12.2

# %%
# !pip install --upgrade typing-extensions
# !pip install nest_asyncio
# Out:
# Requirement already satisfied: typing-extensions in c:\users\dolphinnn\anaconda3\envs\pyt_conda_venv\lib\site-packages (4.12.2)
# Requirement already satisfied: nest_asyncio in c:\users\dolphinnn\anaconda3\envs\pyt_conda_venv\lib\site-packages (1.6.0)

# %%
from bs4 import BeautifulSoup
import ollama
import textwrap
from typing import List, Dict
import re
import asyncio

def clean_html(html):
    """필요 없는 태그를 제거하는 함수"""
    soup = BeautifulSoup(html, "html.parser")

    # 제거할 태그 목록
    remove_tags = ["script", "style", "meta", "link", "iframe", "embed", "object", "noscript"]

    for tag in soup.find_all(remove_tags):
        tag.decompose()  # 해당 태그 제거

    return soup.prettify()

class HTMLAnalyzerBot:
    def __init__(self, model_name: str = "DS_Q4_K_M:v1", chunk_size: int = 4000):
        """
        HTML 분석을 위한 챗봇 초기화
        
        Args:
            model_name (str): 사용할 Ollama 모델 이름
            chunk_size (int): HTML 청크의 최대 크기
        """
        self.model = model_name
        self.chunk_size = chunk_size
        self.chunks: List[str] = []
        self.current_context = ""
        
    def chunk_html(self, html_content: str) -> List[str]:
        """
        HTML을 청크로 분할
        
        Args:
            html_content (str): 분석할 HTML 내용
            
        Returns:
            List[str]: HTML 청크 리스트
        """
        # BeautifulSoup을 사용하여 HTML 파싱
        soup = BeautifulSoup(html_content, 'html.parser')
        
        # 의미 있는 단위로 분할 (예: div, section, article 등)
        meaningful_tags = ['div', 'section', 'article', 'main', 'header', 'footer']
        sections = []
        
        for tag in meaningful_tags:
            elements = soup.find_all(tag)
            for element in elements:
                sections.append(str(element))
        
        # 청크로 나누기
        chunks = []
        current_chunk = ""
        
        for section in sections:
            if len(current_chunk) + len(section) < self.chunk_size:
                current_chunk += section
            else:
                if current_chunk:
                    chunks.append(current_chunk)
                current_chunk = section
        
        if current_chunk:
            chunks.append(current_chunk)
            
        self.chunks = chunks
        return chunks
    
    def add_html_content(self, html_content: str):
        """
        HTML 내용을 추가하고 청킹 수행
        
        Args:
            html_content (str): 추가할 HTML 내용
        """
        self.chunks = self.chunk_html(html_content)
        self.current_context = f"HTML 분석을 시작합니다. 총 {len(self.chunks)}개의 청크가 있습니다."
    
    async def process_chunks(self) -> str:
        """
        모든 HTML 청크를 처리하고 분석
        
        Returns:
            str: 전체 HTML에 대한 분석 결과
        """
        messages = [
            {
                "role": "system",
                "content": "당신은 HTML 코드를 분석하는 전문가입니다. 각 청크를 분석하고, 전체적인 구조와 주요 특징을 파악해주세요."
            }
        ]
        
        # 각 청크 처리
        for i, chunk in enumerate(self.chunks, 1):
            messages.append({
                "role": "user",
                "content": f"청크 {i}/{len(self.chunks)}:\n{chunk}"
            })
            
            response = await ollama.chat(
                model=self.model,
                messages=messages
            )
            
            messages.append({
                "role": "assistant",
                "content": response['message']['content']
            })
        
        # 최종 분석 요청
        messages.append({
            "role": "user",
            "content": "지금까지 분석한 모든 HTML 청크를 종합하여 전체적인 구조와 특징을 요약해주세요."
        })
        
        final_response = await ollama.chat(
            model=self.model,
            messages=messages
        )
        
        return final_response['message']['content']

# 사용 예시
async def analyze_html(html_content: str):
    analyzer = HTMLAnalyzerBot()
    analyzer.add_html_content(html_content)
    result = await analyzer.process_chunks()
    return result

# %%
import nest_asyncio
nest_asyncio.apply()

# 실행 코드
if __name__ == "__main__":
    import asyncio
    
    # 테스트할 URL (예제)
    url = "https://dlchemical.co.kr/"
    response = requests.get(url)

    if response.status_code == 200:
        clean_content = clean_html(response.text)
        print(clean_content)  # 정리된 HTML 출력
    else:
        print("페이지를 가져오지 못했습니다.")    
    
    # 예시 HTML
    html_example = clean_content
    
    # 비동기로 실행
    result = asyncio.run(analyze_html(html_example))
    print(result)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <title>
#    DL케미칼
#   </title>
#   <!--<link rel="stylesheet" type="text/css" href="/assets/ko/library/select2/select2.min.css" />-->
#  </head>
#  <body>
#   <div id="skip">
#    <a href="#content">
#     본문 바로가기
#    </a>
#    <a href="#header">
#     주메뉴 바로 가기
#    </a>
#   </div>
#   <div class="c-wrap">
#    <div class="c-header" id="header">
#     <div class="c-header_aligner">
#      <h1 class="c-h1">
#       <a class="c-logo" href="/ko">
#        DL Chemical
#       </a>
#      </h1>
#      <div class="c-gnb">
#       <ul class="c-gnb_list">
#        <li class="c-gnb_item">
#         <a class="c-gnb_link" href="/ko/intro/info">
#          소개
#         </a>
#        </li>
#        <li class="c-gnb_item">
#         <a class="c-gnb_link" href="/ko/biz/polyethylene">
#          제품
#         </a>
#        </li>
#        <li class="c-gnb_item">
#         <a class="c-gnb_link" href="/ko/esg/management">
#          ESG
#         </a>
#        </li>
#        <li class="c-gnb_item">
#         <a class="c-gnb_link" href="/ko/media/newsroom">
#          미디어
#         </a>
#        </li>
#        <li class="c-gnb_item">
#         <a class="c-gnb_link" href="/ko/recruit">
#          채용
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="c-navi">
#       <a class="c-navi_link c-navi_link--search" href="#">
#        찾기
#       </a>
#       <a class="c-navi_link c-navi_link--drawer" href="#drawer">
#        <span>
#         메뉴
#        </span>
#        <span>
#         닫기
#        </span>
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="c-search" id="search">
#     <div class="c-search_alinger">
#      <div class="c-search_input">
#       <form action="/ko/search" autocomplete="off" name="searchPopForm">
#        <input autocomplete="off" id="" name="search_text" placeholder="검색어를 입력해주세요" type="text"/>
#        <label for="btnSearch" id="btnPopSearch">
#         검색
#        </label>
#       </form>
#      </div>
#     </div>
#    </div>
#    <div class="c-drawer" id="drawer">
#     <div class="c-drawer_aligners">
#      <div class="c-drawer_aligner">
#       <div class="c-drawer_lang">
#        <a class="active" href="#" title="선택됨">
#         KOR
#        </a>
#        <!-- active 클래스 추가 시 활성화 -->
#        <a href="/en">
#         ENG
#        </a>
#        <a href="/cn">
#         CHN
#        </a>
#       </div>
#       <div class="c-drawer_icons">
#        <a class="c-drawer_icon c-drawer_icon--youtube" href="https://www.youtube.com/c/DL%EB%94%94%EC%97%98" target="_blank" title="새창열림">
#         youtube
#        </a>
#       </div>
#       <div class="c-drawer_accordion">
#        <div class="c-drawer_box">
#         <a class="c-drawer_trigger" href="#">
#          소개
#         </a>
#         <div class="c-drawer_cont">
#          <dl>
#           <dt>
#            <a href="/ko/intro/info">
#             정보
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/info">
#               기업정보
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/info?anchor=2">
#               CEO인사말
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/info?anchor=3">
#               사업영역
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/info?anchor=4">
#               재무정보
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/info?anchor=5">
#               CI/BI
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/info?anchor=6">
#               연혁
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/info?anchor=7">
#               Contact
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#          <dl>
#           <dt>
#            <a href="/ko/intro/rnd">
#             R&amp;D
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/rnd">
#               R&amp;D 소개
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/rnd?anchor=2">
#               분야 및 실적
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#          <dl>
#           <dt>
#            <a href="/ko/intro/highlights">
#             그룹 Highlights
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/highlights">
#               DL 그룹
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/highlights?anchor=2">
#               건설
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/highlights?anchor=3">
#               석유화학/에너지
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/intro/highlights?anchor=4">
#               레저/문화/교육
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#         </div>
#        </div>
#        <div class="c-drawer_box">
#         <a class="c-drawer_trigger" href="#">
#          제품
#         </a>
#         <div class="c-drawer_cont">
#          <dl>
#           <dt>
#            <a href="/ko/biz/polyethylene">
#             Polyethylene
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/biz/polyethylene?brand_type=d.fine">
#               D.FINE
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/biz/polyethylene?brand_type=d.xpoly">
#               D.XPOLY
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#          <dl>
#           <dt>
#            <a href="/ko/biz/polybutene">
#             Polybutene
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/biz/polybutene">
#               D.POLYBUTENE
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#          <dl>
#           <dt>
#            <a href="/ko/biz/synthetic">
#             EPO
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/biz/synthetic">
#               D.SYNOL
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#         </div>
#        </div>
#        <div class="c-drawer_box">
#         <a class="c-drawer_trigger" href="#">
#          ESG
#         </a>
#         <div class="c-drawer_cont">
#          <dl>
#           <dt>
#            <a href="/ko/esg/management">
#             ESG 경영
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/management?anchor=2">
#               지속가능경영보고서
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#          <dl>
#           <dt>
#            <a href="/ko/esg/hse">
#             안전·보건·환경(HSE) 경영
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/hse">
#               HSE 방침
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/hse?anchor=2">
#               HSE 목표
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/hse?anchor=3">
#               HSE 경영시스템
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/hse?anchor=4">
#               HSE 활동
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#          <dl>
#           <dt>
#            <a href="/ko/esg/proper">
#             정도경영
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/proper">
#               소개
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/proper?anchor=2">
#               공개경영
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/proper?anchor=3">
#               윤리경영
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/proper?anchor=4">
#               공정거래자율준수(CP)
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/proper?anchor=5">
#               사회적 책임(CSR)
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/proper?anchor=7">
#               사이버 신문고
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#          <dl>
#           <dt>
#            <a href="/ko/esg/winwin">
#             상생경영
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/winwin">
#               소개
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/winwin?anchor=2">
#               협력사 동반성장
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/esg/winwin?anchor=3">
#               사회공헌
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#         </div>
#        </div>
#        <div class="c-drawer_box">
#         <a class="c-drawer_trigger" href="#">
#          미디어
#         </a>
#         <div class="c-drawer_cont">
#          <dl>
#           <dt>
#            <a href="/ko/media/newsroom">
#             뉴스룸
#            </a>
#           </dt>
#           <dd>
#            <ul class="c-drawer_list">
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/media/newsroom?ntype=CD_NWSR_CATE001">
#               보도자료
#              </a>
#             </li>
#             <li class="c-drawer_item">
#              <a class="c-drawer_link" href="/ko/media/newsroom?ntype=CD_NWSR_CATE002">
#               알립니다
#              </a>
#             </li>
#            </ul>
#           </dd>
#          </dl>
#         </div>
#        </div>
#        <div class="c-drawer_box">
#         <a class="c-drawer_trigger" href="/ko/recruit">
#          채용
#         </a>
#        </div>
#       </div>
#       <div class="c-drawer_footer">
#        <div class="c-drawer_navibox">
#         <div class="c-drawer_navi">
#          <a href="/policy/privacy">
#           <span>
#            개인정보처리방침
#           </span>
#          </a>
#          <a href="/policy/video">
#           <span>
#            영상정보기기 운영관리방침
#           </span>
#          </a>
#          <a class="btnLayerPopup" data-target=".email-policy" href="#">
#           <span>
#            이메일무단수집거부
#           </span>
#          </a>
#          <a href="https://eprov.dlchemical.co.kr" target="_blank">
#           <span>
#            인터넷 구매시스템
#           </span>
#          </a>
#          <a href="https://logipartner.daelimcorp.co.kr" target="_blank">
#           <span>
#            출하정보 시스템
#           </span>
#          </a>
#          <!-- s: 220802 -->
#          <a href="/ko/esg/proper?anchor=7" target="_blank">
#           <span>
#            사이버 신문고
#           </span>
#          </a>
#          <!-- e: 220802 -->
#         </div>
#        </div>
#        <div class="c-drawer_info">
#         <p>
#          서울특별시 종로구 통일로 134 D타워
#          <br class="mobile"/>
#          돈의문 26층 DL케미칼
#         </p>
#         <p>
#          Copyright © 2022 DL케미칼. All rights reserved.
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#     <a class="c-drawer_close" href="#">
#      메뉴닫기
#     </a>
#    </div>
#    <div class="c-container" id="content">
#     <div class="main">
#      <section class="m-section" id="section01">
#       <div class="m-visual">
#        <div class="m-visual_aligner">
#         <div class="m-visual_txtbox">
#          <div class="m-visual_heading">
#           <p data-aos="fade-left" data-aos-delay="100" data-aos-duration="500">
#            케미칼의
#           </p>
#           <p data-aos="fade-left" data-aos-delay="200" data-aos-duration="500">
#            기본이 됩니다
#           </p>
#          </div>
#          <div class="m-visual_since" data-aos="fade-up" data-aos-delay="300" data-aos-duration="800">
#           since
#           <strong>
#            1979
#           </strong>
#          </div>
#          <div class="m-visual_txt" data-aos="fade-up" data-aos-delay="300" data-aos-duration="1000">
#           DL케미칼은 세계 최고 수준의 R&amp;D 역량과
#           <br class="mobile"/>
#           전략적 제휴를 기반으로
#           <br/>
#           세계 수준의 석유화학 기업으로 거듭나고 있습니다
#          </div>
#         </div>
#         <div class="m-picture" data-aos="fade-up" data-aos-delay="300" data-aos-duration="800">
#          <div class="m-picture_txtbox">
#           <div class="m-picture_txt m-picture_txt-1">
#            World Leading
#            <br/>
#            Petrochemical
#            <br/>
#            Company
#           </div>
#           <div class="m-picture_txt m-picture_txt-2">
#            Chemical
#           </div>
#          </div>
#          <div class="m-picture_image" data-aos="fade" data-aos-anchor=".m-picture_txt-2">
#           <img alt="" src="/assets/ko/images/pages/m-picture.png"/>
#          </div>
#         </div>
#        </div>
#       </div>
#      </section>
#      <section class="m-section" id="section02">
#       <div class="m-technology">
#        <div class="m-technology_heading" data-aos="fade">
#         <div class="c-aligner">
#          <div class="m-heading">
#           <div class="m-heading_detail" data-aos="fade-up" data-aos-delay="100" data-aos-duration="500">
#            신뢰의 기본이 됩니다
#           </div>
#           <p class="m-heading_txt" data-aos="fade-up" data-aos-delay="200" data-aos-duration="500">
#            DL케미칼은 신뢰받는
#           </p>
#           <p class="m-heading_txt" data-aos="fade-up" data-aos-delay="250" data-aos-duration="500">
#            기술력을 바탕으로
#           </p>
#           <p class="m-heading_txt" data-aos="fade-up" data-aos-delay="300" data-aos-duration="500">
#            고객의 가치를 향상시킵니다
#           </p>
#          </div>
#         </div>
#        </div>
#        <div class="m-technology_slider">
#         <div class="c-aligner">
#          <div class="m-slider">
#           <div class="m-slider_list" data-aos="fade-left" data-aos-delay="200" data-aos-duration="1000">
#            <div class="m-slider_item active">
#             <div class="m-technology_box">
#              <div class="m-technology_images">
#               <div class="m-technology_image">
#                <img alt="" src="/assets/ko/images/pages/m-technology_image-0.jpg"/>
#               </div>
#              </div>
#              <div class="m-technology_cont">
#               <div class="m-technology_logo">
#                <img alt="DL Chemical" src="/assets/ko/images/pages/m-technology_logo-0.svg"/>
#               </div>
#               <div class="m-technology_sheading">
#                독자적 메탈로센 기술의 PE,
#                <br>
#                 세계 점유율 No.1 PB,
#                 <br>
#                  프리미엄 점도조절제 EPO
#                 </br>
#                </br>
#               </div>
#               <div class="m-technology_txt">
#                케미칼 제품 생산능력,
#                <em>
#                 915KTA
#                </em>
#                <br>
#                 2021년 기준 매출액,
#                 <em>
#                  1.6조원
#                 </em>
#                </br>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-technology_box">
#              <div class="m-technology_images">
#               <div class="m-technology_image">
#                <img alt="" src="/assets/ko/images/pages/m-technology_image-1.jpg"/>
#               </div>
#              </div>
#              <div class="m-technology_cont">
#               <div class="m-technology_logo">
#                <img alt="KRATON" src="/assets/ko/images/pages/m-technology_logo-1.svg"/>
#               </div>
#               <div class="m-technology_sheading">
#                글로벌 스페셜티 폴리머와
#                <br/>
#                파인 케미칼
#                <br/>
#                시장의 선도 기업
#               </div>
#               <div class="m-technology_txt">
#                약
#                <em>
#                 1,000
#                </em>
#                개 이상의 기술특허
#                <br/>
#                바이오 케미칼 생산 능력,
#                <em>
#                 700KTA
#                </em>
#                <br/>
#                2021년 기준 매출액 약,
#                <em>
#                 2조원
#                </em>
#               </div>
#               <div class="m-technology_mores">
#                <a class="m-technology_more" href="https://kraton.com" target="_blank">
#                 more
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-technology_box">
#              <div class="m-technology_images">
#               <div class="m-technology_image">
#                <img alt="" src="/assets/ko/images/pages/m-technology_image-2.jpg"/>
#               </div>
#              </div>
#              <div class="m-technology_cont">
#               <div class="m-technology_logo">
#                <img alt="DL FnC" src="/assets/ko/images/pages/m-technology_logo-2.svg"/>
#               </div>
#               <div class="m-technology_sheading">
#                BOPP Film,
#                <br>
#                 EVA Coated Film,
#                 <br>
#                  특수코팅 Film 전문회사
#                 </br>
#                </br>
#               </div>
#               <div class="m-technology_txt">
#                BOPP 생산 능력,
#                <em>
#                 32KTA
#                </em>
#                <br>
#                 2021년 기준 매출액 약,
#                 <em>
#                  950억원
#                 </em>
#                </br>
#               </div>
#               <div class="m-technology_mores">
#                <a class="m-technology_more" href="https://www.dlfnc.co.kr" target="_blank">
#                 more
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-technology_box">
#              <div class="m-technology_images">
#               <div class="m-technology_image">
#                <img alt="" src="/assets/ko/images/pages/m-technology_image-3.jpg"/>
#               </div>
#              </div>
#              <div class="m-technology_cont">
#               <div class="m-technology_logo">
#                <img alt="Cariflex" src="/assets/ko/images/pages/m-technology_logo-3.svg"/>
#               </div>
#               <div class="m-technology_sheading">
#                합성고무 및 합성고무 라텍스
#                <br>
#                 제조 및 판매
#                 <br>
#                  수술장갑 분야 글로벌 No.1
#                 </br>
#                </br>
#               </div>
#               <div class="m-technology_txt">
#                2021년 기준 매출액 약,
#                <em>
#                 2,600억원
#                </em>
#               </div>
#               <div class="m-technology_mores">
#                <a class="m-technology_more" href="https://www.cariflex.com" target="_blank">
#                 more
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-technology_box">
#              <div class="m-technology_images">
#               <div class="m-technology_image">
#                <img alt="" src="/assets/ko/images/pages/m-technology_image-4.jpg"/>
#               </div>
#              </div>
#              <div class="m-technology_cont">
#               <div class="m-technology_logo">
#                <img alt="D-REX Polymer" src="/assets/ko/images/pages/m-technology_logo-4.svg"/>
#               </div>
#               <div class="m-technology_sheading">
#                핫멜트 접착제 소재
#                <br>
#                 무정형 폴리 알파 올레핀
#                 <br/>
#                 (Amorphous Poly Alpha Olefin)
#                 <br/>
#                 전문회사
#                </br>
#               </div>
#               <div class="m-technology_txt">
#                2021년 12월 착공
#                <br/>
#                2023년 상반기
#                <em>
#                 4만톤
#                </em>
#                규모 생산 시작
#               </div>
#               <div class="m-technology_mores">
#                <a class="m-technology_more" href="https://www.drexpolymer.com/" target="_blank">
#                 more
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-technology_box">
#              <div class="m-technology_images">
#               <div class="m-technology_image">
#                <img alt="" src="/assets/ko/images/pages/m-technology_image-7.jpg"/>
#               </div>
#              </div>
#              <div class="m-technology_cont">
#               <div class="m-technology_logo">
#                <img alt="NOTARK" src="/assets/ko/images/pages/m-technology_logo-7.svg"/>
#               </div>
#               <div class="m-technology_sheading">
#                미래 제품을 개발 하는
#                <br/>
#                혁신 기업
#               </div>
#               <div class="m-technology_txt">
#                혁신 제품의 개발 및 상업화 위해 2023년 설립
#                <br/>
#                초고속 통신 장비용 절연 레진 노탁(Notark™ )개발
#                <br/>
#                미래 에너지 솔루션 용 이온 전도성 폴리머 등 다양한 기술 플랫폼 개발 중
#               </div>
#               <!-- 24.02.19 버튼 숨김처리
# 											<div class="m-technology_mores">
# 												<a href="https://www.notark.com" target="_blank" class="m-technology_more">more</a>
# 											</div>
# 											-->
#              </div>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-technology_box">
#              <div class="m-technology_images">
#               <div class="m-technology_image">
#                <img alt="" src="/assets/ko/images/pages/m-technology_image-5.jpg"/>
#               </div>
#              </div>
#              <div class="m-technology_cont">
#               <div class="m-technology_logo">
#                <img alt="Poly Mirae" src="/assets/ko/images/pages/m-technology_logo-5.svg"/>
#               </div>
#               <div class="m-technology_sheading">
#                <p>
#                 DL케미칼 50% : LyondellBasell 50%
#                </p>
#                마스크, 자동차 내외장재 용
#                <br/>
#                Specialty 폴리프로필렌
#                <br/>
#                전문회사
#               </div>
#               <div class="m-technology_txt">
#                PP 생산 능력,
#                <em>
#                 730KTA
#                </em>
#                <br/>
#                2021년 기준 매출액 약,
#                <em>
#                 1조원
#                </em>
#               </div>
#               <div class="m-technology_mores">
#                <a class="m-technology_more" href="https://www.polymirae.com" target="_blank">
#                 more
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-technology_box">
#              <div class="m-technology_images">
#               <div class="m-technology_image">
#                <img alt="" src="/assets/ko/images/pages/m-technology_image-6.jpg"/>
#               </div>
#              </div>
#              <div class="m-technology_cont">
#               <div class="m-technology_logo">
#                <img alt="YNCC" src="/assets/ko/images/pages/m-technology_logo-6-2.svg"/>
#               </div>
#               <div class="m-technology_sheading">
#                <p>
#                 DL케미칼 50% : 한화솔루션 50%
#                </p>
#                국내 최대 나프타 분해 업체
#                <br/>
#                에틸렌, 프로필렌, 부타디엔 등
#                <br/>
#                기초 원료 생산
#               </div>
#               <div class="m-technology_txt">
#                에틸렌 생산 능력,
#                <em>
#                 2300KTA
#                </em>
#                <br/>
#                프로필렌 생산 능력,
#                <em>
#                 1,300KTA
#                </em>
#                <br/>
#                2021년 기준 매출액 약,
#                <em>
#                 6조원
#                </em>
#               </div>
#               <div class="m-technology_mores">
#                <a class="m-technology_more" href="https://www.yncc.co.kr" target="_blank">
#                 more
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <!-- // 220423 퍼블 수정 -->
#         </div>
#        </div>
#       </div>
#      </section>
#      <section class="m-section m-section--none" id="section04">
#       <div class="m-info">
#        <div class="m-info_aligner">
#         <div class="m-info_box">
#          <div class="m-info_tabboxs">
#           <div class="m-info_tabbox">
#            <div class="m-info_heading" data-aos="fade-left" data-aos-delay="300" data-aos-duration="500">
#             혁신의 기본이 됩니다
#            </div>
#            <div class="m-info_tabs">
#             <ul class="m-info_tab">
#              <li data-aos="fade-up" data-aos-anchor=".m-info_tab" data-aos-delay="800" data-aos-duration="600">
#               <a href="#">
#                47년
#               </a>
#              </li>
#              <!-- active클래스 추가 시 활성화 -->
#              <li data-aos="fade-up" data-aos-anchor=".m-info_tab" data-aos-delay="850" data-aos-duration="600">
#               <a href="#">
#                기술 선도 기업
#               </a>
#              </li>
#              <li data-aos="fade-up" data-aos-anchor=".m-info_tab" data-aos-delay="900" data-aos-duration="600">
#               <a href="#">
#                세계 1위 제품
#               </a>
#              </li>
#              <li data-aos="fade-up" data-aos-anchor=".m-info_tab" data-aos-delay="1000" data-aos-duration="600">
#               <a href="#">
#                글로벌 기업 도약
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#          <div class="m-info_imagelistbox">
#           <div class="m-info_imagelists" data-aos="fade-up" data-aos-delay="1300" data-aos-duration="700">
#            <div class="m-info_imagelist">
#             <div class="m-info_imageitem">
#              <div class="m-info_imagebox">
#               <div class="m-info_image">
#                <img alt="" src="/assets/ko/images/pages/m-info_image-1.png"/>
#               </div>
#              </div>
#             </div>
#             <div class="m-info_imageitem">
#              <div class="m-info_imagebox">
#               <div class="m-info_image">
#                <img alt="" src="/assets/ko/images/pages/m-info_image-2.png"/>
#               </div>
#              </div>
#             </div>
#             <div class="m-info_imageitem">
#              <div class="m-info_imagebox">
#               <div class="m-info_image">
#                <img alt="" src="/assets/ko/images/pages/m-info_image-3.png"/>
#               </div>
#              </div>
#             </div>
#             <div class="m-info_imageitem">
#              <div class="m-info_imagebox">
#               <div class="m-info_image">
#                <img alt="" src="/assets/ko/images/pages/m-info_image-4.png"/>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="m-info_txtlist" data-aos="fade-right" data-aos-delay="1600" data-aos-duration="800">
#            <div class="m-info_txtitem active">
#             <div class="m-info_txtbox">
#              <div class="m-info_txt">
#               47 년 역사의 설비 및 생산 운영 노하우를 바탕으로
#               <br/>
#               DL케미칼은 석유화학업계의 선도 기업으로 성장하고 있습니다.
#              </div>
#             </div>
#            </div>
#            <div class="m-info_txtitem">
#             <div class="m-info_txtbox">
#              <div class="m-info_txt">
#               DL케미칼은 미국 시장에 기술을 수출한 국내 최초의 기업입니다. 또한, 세계 두번째로 차세대 메탈로센 폴리에틸렌의 개발에 성공, 그 기술력을 인정 받고 있습니다.
#              </div>
#             </div>
#            </div>
#            <div class="m-info_txtitem">
#             <div class="m-info_txtbox">
#              <div class="m-info_txt">
#               DL케미칼은 글로벌 폴리부텐(PB)시장의 1위 (오픈마켓 기준) 기업입니다.  또한, 합성고무를 생산하는 자회사인 카리플렉스는 수술용 고무장갑 원료 시장의 75%를 차지하고 있습니다.
#              </div>
#             </div>
#            </div>
#            <div class="m-info_txtitem">
#             <div class="m-info_txtbox">
#              <div class="m-info_txt">
#               DL케미칼은 미/유럽 SBC 시장
# 											1위 기업 크레이튼 인수,
# 											친환경 접착제 생산 기업 디렉스
# 											폴리머 설립 등 글로벌 시장으로
# 											도약하기 위한 준비를 마쳤습니다.
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="m-info_slide" data-aos="fade-up" data-aos-delay="800" data-aos-duration="800">
#           <div class="m-info_slidelist">
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </section>
#      <section class="m-section m-section--none" id="section05">
#       <div class="m-news">
#        <div class="m-news_heading">
#         <div class="c-aligner">
#          <div class="m-heading">
#           <div class="m-heading_detail" data-aos="fade-left" data-aos-delay="100" data-aos-duration="500">
#            성장의 기본이 됩니다
#           </div>
#           <p class="m-heading_txt" data-aos="fade-left" data-aos-delay="200" data-aos-duration="500">
#            환경을 위한 실천과
#            <br class="mobile"/>
#            고객과의 소통을 통해
#           </p>
#           <p class="m-heading_txt" data-aos="fade-left" data-aos-delay="250" data-aos-duration="500">
#            지속가능한 미래를 만들어갑니다
#           </p>
#          </div>
#         </div>
#        </div>
#        <div class="m-news_slider" data-aos="fade-left" data-aos-delay="350" data-aos-duration="1000">
#         <div class="c-aligner">
#          <div class="m-slider">
#           <div class="m-slider_list">
#            <div class="m-slider_item active">
#             <div class="m-news_box">
#              <div class="m-news_images">
#               <div class="m-news_image">
#                <img alt="DL케미칼, 국내 주요 대학 채용박람회로 인재 확보 나서 " src="/upload/news/thumb1/282/7K7dbkHdUKG.jpg"/>
#               </div>
#              </div>
#              <div class="m-news_cont">
#               <div class="m-news_date">
#                2023.03.03
#               </div>
#               <div class="m-news_subject">
#                DL케미칼, 국내 주요 대학 채용박람회로 인재 확보 나서
#               </div>
#               <div class="m-news_tag">
#                <span>
#                 #보도자료
#                </span>
#               </div>
#               <div class="m-news_mores">
#                <a class="m-news_more" href="https://www.dlchemical.co.kr/ko/media/newsroom/47" target="_blank">
#                 more
#                </a>
#               </div>
#              </div>
#              <a class="all-area-link" href="https://www.dlchemical.co.kr/ko/media/newsroom/47" target="_blank">
#               more
#              </a>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-news_box">
#              <div class="m-news_images">
#               <div class="m-news_image">
#                <img alt="DL케미칼, 따뜻한 연탄 나눔으로 에너지 소외계층 지원  " src="/upload/news/thumb1/281/4utlPKbtfo.jpg"/>
#               </div>
#              </div>
#              <div class="m-news_cont">
#               <div class="m-news_date">
#                2022.12.13
#               </div>
#               <div class="m-news_subject">
#                DL케미칼, 따뜻한 연탄 나눔으로 에너지 소외계층 지원
#               </div>
#               <div class="m-news_tag">
#                <span>
#                 #보도자료
#                </span>
#               </div>
#               <div class="m-news_mores">
#                <a class="m-news_more" href="https://www.dlchemical.co.kr/ko/media/newsroom/46" target="_blank">
#                 more
#                </a>
#               </div>
#              </div>
#              <a class="all-area-link" href="https://www.dlchemical.co.kr/ko/media/newsroom/46" target="_blank">
#               more
#              </a>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-news_box">
#              <div class="m-news_images">
#               <div class="m-news_image">
#                <img alt="준법경영 시스템 국제표준 ‘ISO 37301 인증 획득" src="/upload/news/thumb1/280/FJT7YAxOdKneLs8HhLbIIrvbrG5XcDn7x7e2WGr.jpg"/>
#               </div>
#              </div>
#              <div class="m-news_cont">
#               <div class="m-news_date">
#                2022.09.26
#               </div>
#               <div class="m-news_subject">
#                준법경영 시스템 국제표준 ‘ISO 37301 인증 획득
#               </div>
#               <div class="m-news_tag">
#                <span>
#                 #보도자료
#                </span>
#               </div>
#               <div class="m-news_mores">
#                <a class="m-news_more" href="https://www.dlchemical.co.kr/ko/media/newsroom/44" target="_blank">
#                 more
#                </a>
#               </div>
#              </div>
#              <a class="all-area-link" href="https://www.dlchemical.co.kr/ko/media/newsroom/44" target="_blank">
#               more
#              </a>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-news_box">
#              <div class="m-news_images">
#               <div class="m-news_image">
#                <img alt="DL케미칼, 수출용 제품에 재활용 포장백 대폭 적용" src="/upload/news/thumb1/279/LLWY1rRl.jpg"/>
#               </div>
#              </div>
#              <div class="m-news_cont">
#               <div class="m-news_date">
#                2022.06.27
#               </div>
#               <div class="m-news_subject">
#                DL케미칼, 수출용 제품에 재활용 포장백 대폭 적용
#               </div>
#               <div class="m-news_tag">
#                <span>
#                 #보도자료
#                </span>
#               </div>
#               <div class="m-news_mores">
#                <a class="m-news_more" href="https://www.dlchemical.co.kr/ko/media/newsroom/37" target="_self">
#                 more
#                </a>
#               </div>
#              </div>
#              <a class="all-area-link" href="https://www.dlchemical.co.kr/ko/media/newsroom/37" target="_self">
#               more
#              </a>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-news_box">
#              <div class="m-news_images">
#               <div class="m-news_image">
#                <img alt="DL케미칼, 환경공단 영농 폐비닐 재활용 MOU 체결" src="/upload/news/thumb1/277/7oyPD38.jpg"/>
#               </div>
#              </div>
#              <div class="m-news_cont">
#               <div class="m-news_date">
#                2022.05.10
#               </div>
#               <div class="m-news_subject">
#                DL케미칼, 환경공단 영농 폐비닐 재활용 MOU 체결
#               </div>
#               <div class="m-news_tag">
#                <span>
#                 #보도자료
#                </span>
#               </div>
#               <div class="m-news_mores">
#                <a class="m-news_more" href="https://www.dlchemical.co.kr/ko/media/newsroom/34" target="_self">
#                 more
#                </a>
#               </div>
#              </div>
#              <a class="all-area-link" href="https://www.dlchemical.co.kr/ko/media/newsroom/34" target="_self">
#               more
#              </a>
#             </div>
#            </div>
#            <div class="m-slider_item">
#             <div class="m-news_box">
#              <div class="m-news_images">
#               <div class="m-news_image">
#                <img alt="DL케미칼 세계포장기구(WPO) 월드스타 어워드 수상" src="/upload/news/thumb1/276/3tUpFPdmLPoAVWxUxVp2gFwXTm2GVCFa53.png"/>
#               </div>
#              </div>
#              <div class="m-news_cont">
#               <div class="m-news_date">
#                2022.05.10
#               </div>
#               <div class="m-news_subject">
#                DL케미칼 세계포장기구(WPO) 월드스타 어워드 수상
#               </div>
#               <div class="m-news_tag">
#                <span>
#                 #알립니다
#                </span>
#               </div>
#               <div class="m-news_mores">
#                <a class="m-news_more" href="https://www.dlchemical.co.kr/ko/media/newsroom/32" target="_blank">
#                 more
#                </a>
#               </div>
#              </div>
#              <a class="all-area-link" href="https://www.dlchemical.co.kr/ko/media/newsroom/32" target="_blank">
#               more
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </section>
#     </div>
#    </div>
#    <div class="c-banner">
#     <div class="c-banner_aligner">
#      <div class="c-banner_box">
#       <div class="c-banner_slidebox">
#        <div class="c-banner_slide">
#         <div class="c-banner_list">
#         </div>
#        </div>
#        <div class="c-banner_function">
#         <div class="inline">
#          <div class="c-check">
#           <input id="banner-today" name="banner-today" type="checkbox">
#            <label for="banner-today">
#             오늘 다시보지 않음
#            </label>
#           </input>
#          </div>
#         </div>
#         <div class="inline">
#          <a class="c-banner_close" href="#">
#           팝업닫기
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="c-sharebox" style="display:none;">
#     <div class="c-share_snsbox">
#      <ul class="c-share_sns">
#       <li class="c-share_sns-2">
#        <a class="btnFacebook" href="#">
#         페이스북
#        </a>
#       </li>
#       <li class="c-share_sns-3">
#        <a class="btnTwitter" href="#">
#         트위터
#        </a>
#       </li>
#       <li class="c-share_sns-4">
#        <a class="btnBlog" href="#">
#         블로그
#        </a>
#       </li>
#       <li class="c-share_sns-5">
#        <a class="btnLinkedIn" href="#">
#         Linkedin
#        </a>
#       </li>
#       <li class="c-share_sns-7">
#        <a class="btnClipboard" href="#">
#         URL 복사
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="c-top">
#     <a href="#">
#      Top
#     </a>
#    </div>
#    <div class="c-footer">
#     <div class="c-footer_aligner">
#      <div class="c-footer_heading">
#       <a class="c-footer_logo" href="/">
#        DL Chemical
#       </a>
#      </div>
#      <ul class="c-footer_list">
#       <li>
#        <a href="/ko/policy/privacy">
#         개인정보처리방침
#        </a>
#       </li>
#       <li>
#        <a href="/ko/policy/video">
#         영상정보처리기기운영관리방침
#        </a>
#       </li>
#       <li>
#        <a class="btnLayerPopup" data-target=".email-policy" href="#">
#         이메일무단수집거부
#        </a>
#       </li>
#       <li>
#        <a href="/ko/esg/proper?anchor=7">
#         사이버 신문고
#        </a>
#       </li>
#      </ul>
#      <a class="c-partner_trigger" href="#partner">
#       계열사 바로가기
#      </a>
#      <div class="c-partner" id="partner">
#       <div class="c-partner_aligner">
#        <div class="c-partner_box">
#         <div class="c-partner_section">
#          <h2 class="c-partner_heading">
#           계열사 사이트
#          </h2>
#          <div class="c-partner_listboxs">
#           <div class="c-partner_listbox">
#            <h3 class="c-partner_sheading">
#             건설
#            </h3>
#            <ul class="c-partner_list">
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://www.dlenc.co.kr" target="_blank">
#               DL이앤씨
#              </a>
#             </li>
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://dlconstruction.co.kr" target="_blank">
#               DL건설
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="c-partner_listbox">
#            <h3 class="c-partner_sheading">
#             석유화학
#            </h3>
#            <ul class="c-partner_list">
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="#" target="_blank">
#               DL케미칼
#              </a>
#             </li>
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://www.dlfnc.co.kr" target="_blank">
#               DL에프앤씨
#              </a>
#             </li>
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://www.yncc.co.kr" target="_blank">
#               여천NCC
#              </a>
#             </li>
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://www.polymirae.com" target="_blank">
#               폴리미래
#              </a>
#             </li>
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://www.cariflex.com" target="_blank">
#               CARIFLEX
#              </a>
#             </li>
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://kraton.com" target="_blank" title="새창열림">
#               KRATON
#              </a>
#             </li>
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://www.drexpolymer.com" target="_blank" title="새창열림">
#               디렉스폴리머
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="c-partner_listbox">
#            <h3 class="c-partner_sheading">
#             에너지/제조
#            </h3>
#            <ul class="c-partner_list">
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="http://www.dlenergy.co.kr" target="_blank">
#               DL에너지
#              </a>
#             </li>
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="http://www.dlmotors.co.kr">
#               DL모터스
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="c-partner_listbox">
#            <h3 class="c-partner_sheading">
#             레저
#            </h3>
#            <ul class="c-partner_list">
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://www.glad-hotels.com" target="_blank">
#               글래드 호텔앤리조트
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="c-partner_listbox">
#            <h3 class="c-partner_sheading">
#             문화
#            </h3>
#            <ul class="c-partner_list">
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://daelimmuseum.org/daelimculturalfoundation" target="_blank">
#               대림문화재단
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="c-partner_listbox">
#            <h3 class="c-partner_sheading">
#             교육
#            </h3>
#            <ul class="c-partner_list">
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://www.suam.or.kr" target="_blank">
#               대림수암장학문화재단
#              </a>
#             </li>
#             <li class="c-partner_item">
#              <a class="c-partner_link" href="https://www.daelim.ac.kr" target="_blank">
#               대림학원
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#         <div class="c-partner_section">
#          <div class="c-partner_halfs">
#           <div class="c-partner_half">
#            <h2 class="c-partner_heading">
#             브랜드 페이지
#            </h2>
#            <div class="c-partner_listboxs">
#             <div class="c-partner_listbox">
#              <ul class="c-partner_list">
#               <li class="c-partner_item">
#                <a class="c-partner_link" href="https://www.elife.co.kr" target="_blank">
#                 e편한세상
#                </a>
#               </li>
#               <li class="c-partner_item">
#                <a class="c-partner_link" href="https://www.acro.co.kr" target="_blank">
#                 아크로
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </div>
#           <div class="c-partner_half">
#            <h2 class="c-partner_heading">
#             기타/업무 관련 사이트
#            </h2>
#            <div class="c-partner_listboxs">
#             <div class="c-partner_listbox">
#              <ul class="c-partner_list">
#               <li class="c-partner_item">
#                <a class="c-partner_link" href="#">
#                 인터넷 구매시스템
#                </a>
#               </li>
#               <li class="c-partner_item">
#                <a class="c-partner_link" href="#">
#                 출하정보 시스템
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <a class="c-partner_close" href="#">
#          계열사 바로가기 팝업 닫기
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="c-popup email-policy">
#     <div class="c-popup_aligner">
#      <div class="c-popup_box">
#       <div class="c-popup_headings">
#        <div class="c-popup_heading">
#         이메일무단수집거부
#        </div>
#        <!-- 220509 퍼블리싱 수정 -->
#       </div>
#       <div class="c-popup_cont">
#        <div class="c-popup_txt">
#         본 웹사이트에 게시된 이메일 주소가 전자우편 수집 프로그램이나 그 밖의 기술적 장치를 이용한 무단으로 수집되는 것을 거부하며, 이를 위반 시
#         <em>
#          정보통신망법에 의해 형사처벌
#         </em>
#         됨을 유념하시기 바랍니다.
#         <br/>
#         <br/>
#         게시일 : 2010년 12월 1일
#        </div>
#        <div class="c-popup_buttons">
#         <a class="c-popup_button" href="#">
#          확인
#         </a>
#        </div>
#       </div>
#       <a class="c-popup_close" href="#">
#        팝업닫기
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 18
#      15 html_example = clean_content
#      17 # 비동기로 실행
# ---> 18 result = await main(html_example)
#      19 print(result)
#
# Cell In[4], line 137, in main(html_example)
#     135 async def main(html_example):
#     136     # 비동기 작업 수행
# --> 137     result = asyncio.run(analyze_html(html_example))
#     138     print("작업 완료")
#     140     return result
#
# File c:\Users\Dolphinnn\anaconda3\envs\PyT_conda_venv\lib\asyncio\runners.py:33, in run(main, debug)
#       9 """Execute the coroutine and return the result.
#      10
#      11 This function runs the passed coroutine, taking care of
#    (...)
#      30     asyncio.run(main())
#      31 """
#      32 if events._get_running_loop() is not None:
# ---> 33     raise RuntimeError(
#      34         "asyncio.run() cannot be called from a running event loop")
#      36 if not coroutines.iscoroutine(main):
#      37     raise ValueError("a coroutine was expected, got {!r}".format(main))
#
# RuntimeError: asyncio.run() cannot be called from a running event loop
